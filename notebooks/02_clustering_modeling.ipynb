# %% [markdown]
# # 02 — Modelado de Clustering
# Preprocesamiento, reducción dimensional (PCA/t-SNE) y K-Means.

# %%
import sys, os
sys.path.append(os.path.abspath(".."))  # raiz del proyecto en el path

# %%
from src import config, preprocessing, dimensionality_reduction, clustering
config.ensure_dirs()

# %% [markdown]
# ## Fase 2 — Preprocesamiento

# %%
df_proc = preprocessing.run()
df_proc.head()

# %% [markdown]
# ## Fase 3 — Reducción dimensional (PCA + t-SNE)

# %%
df_pca = dimensionality_reduction.run(df_proc)
df_pca.head()

# %% [markdown]
# ## Fase 4 — K-Means

# %%
assignments = clustering.run(df_pca)
assignments['kmeans_cluster'].value_counts()
