# %% [markdown]
# # 01 — Análisis Exploratorio (EDA)
# Genera los datos (si faltan) y ejecuta la Fase 1.

# %%
import sys, os
sys.path.append(os.path.abspath(".."))  # raiz del proyecto en el path

# %%
from src import config, data_generation, eda
import pandas as pd
config.ensure_dirs()

# %% [markdown]
# ## Generar / cargar datos

# %%
if not config.RAW_CSV.exists():
    df = data_generation.run(1500)
else:
    df = pd.read_csv(config.RAW_CSV)
df.head()

# %% [markdown]
# ## Resumen de outliers + heatmap de correlación

# %%
outliers = eda.run(df)
outliers

# %% [markdown]
# La figura de correlación se guarda en `reports/figures/correlation_heatmap.png`.
