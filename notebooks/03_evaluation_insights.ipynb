# %% [markdown]
# # 03 — Evaluación e Insights
# Perfilado de clusters y mapeo a personas de negocio.

# %%
import sys, os
sys.path.append(os.path.abspath(".."))  # raiz del proyecto en el path

# %%
from src import config, profiling
import pandas as pd
config.ensure_dirs()

# %% [markdown]
# ## Fase 5 — Perfilado + personas

# %%
personas = profiling.run()
personas

# %% [markdown]
# ## Perfil numérico por cluster

# %%
pd.read_csv(config.REPORTS / 'tables' / 'cluster_numeric_profile.csv')

# %% [markdown]
# Salidas guardadas en `reports/cluster_persona_mapping.csv` y `reports/tables/cluster_numeric_profile.csv`.
